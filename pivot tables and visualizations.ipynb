# %%
import os
os.chdir("D:/R and PYTHON files/csv output")
os.getcwd()
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df1=pd.read_excel("Takenmind_intern.xlsx",sheet_name='3')
df2=pd.read_excel("Takenmind_intern.xlsx",sheet_name='2')
df3=pd.read_excel("Takenmind_intern.xlsx",sheet_name='4')
df3.head(2)
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.38             0.53               2
# 1       2                0.80             0.86               5
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
#
#    promotion_last_5years   dept  salary Whether the employee has left
# 0                      0  sales     low                           yes
# 1                      0  sales  medium                           yes

# %%
#df4=df1.pivot("Emp ID","dept","promotion_last_5years")

# %%
#sns.heatmap(df4).get_figure()
#df5=df2.pivot("Emp ID","dept","promotion_last_5years")
#sns.heatmap(df5).get_figure()

# %%
#sns.heatmap(df4).get_figure().savefig('ht.png')
df1['dept'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df1['dept'].value_counts()
# Out:
# sales          1014
# technical       697
# support         555
# IT              273
# hr              215
# accounting      204
# marketing       203
# product_mng     198
# RandD           121
# management       91
# Name: dept, dtype: int64

# %%
df2['dept'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'RandD', 'marketing'], dtype=object)

# %%
df2['dept'].value_counts()
# Out:
# sales          3126
# technical      2023
# support        1674
# IT              954
# product_mng     704
# RandD           666
# marketing       655
# accounting      563
# management      539
# hr              524
# Name: dept, dtype: int64

# %%
df1['satisfaction_level'].value_counts()
# Out:
# 0.10    358
# 0.11    335
# 0.09    195
# 0.37    194
# 0.43    178
# 0.40    169
# 0.45    157
# 0.38    154
# 0.44    153
# 0.39    140
# 0.41    132
# 0.42    108
# 0.36     96
# 0.46     68
# 0.84     62
# 0.82     58
# 0.87     58
# 0.89     56
# 0.90     52
# 0.81     51
# 0.77     51
# 0.74     51
# 0.78     50
# 0.83     47
# 0.79     45
# 0.76     45
# 0.91     43
# 0.73     42
# 0.86     41
# 0.75     38
#        ...
# 0.60      4
# 0.55      4
# 0.63      4
# 0.12      4
# 0.71      4
# 0.47      4
# 0.20      4
# 0.34      4
# 0.13      3
# 0.28      3
# 0.50      3
# 0.25      3
# 0.24      3
# 0.15      3
# 0.58      3
# 0.33      3
# 0.35      3
# 0.64      2
# 0.23      2
# 0.62      2
# 0.30      2
# 0.49      2
# 0.65      1
# 0.16      1
# 0.22      1
# 0.26      1
# 0.67      1
# 0.68      1
# 0.29      1
# 0.21      1
# Name: satisfaction_level, Length: 81, dtype: int64

# %%
df2['satisfaction_level'].value_counts()
# Out:
# 0.50    226
# 0.66    217
# 0.59    212
# 0.69    209
# 0.49    207
# 0.74    206
# 0.63    205
# 0.73    204
# 0.96    203
# 0.57    202
# 0.61    202
# 0.77    201
# 0.72    200
# 0.65    198
# 0.52    196
# 0.70    195
# 0.80    194
# 0.78    191
# 0.60    189
# 0.76    189
# 0.75    188
# 0.83    187
# 0.62    186
# 0.84    185
# 0.64    185
# 0.98    183
# 0.82    183
# 0.51    182
# 0.56    182
# 0.89    181
#        ...
# 0.20     65
# 0.14     63
# 0.18     63
# 0.22     59
# 0.44     58
# 0.23     52
# 0.13     51
# 0.42     47
# 0.37     47
# 0.43     46
# 0.45     46
# 0.34     44
# 0.36     43
# 0.32     42
# 0.31     42
# 0.40     40
# 0.41     39
# 0.47     38
# 0.29     37
# 0.30     37
# 0.38     35
# 0.39     35
# 0.35     34
# 0.33     33
# 0.25     31
# 0.26     29
# 0.28     28
# 0.46     27
# 0.12     26
# 0.27     24
# Name: satisfaction_level, Length: 89, dtype: int64

# %%
df1['promotion_last_5years'].value_counts()
# Out:
# 0    3552
# 1      19
# Name: promotion_last_5years, dtype: int64

# %%
df2['promotion_last_5years'].value_counts()
# Out:
# 0    11128
# 1      300
# Name: promotion_last_5years, dtype: int64

# %%
df1['Work_accident'].value_counts()
# Out:
# 0    3402
# 1     169
# Name: Work_accident, dtype: int64

# %%
df2['Work_accident'].value_counts()
# Out:
# 0    9428
# 1    2000
# Name: Work_accident, dtype: int64

# %%
df1['salary'].value_counts()
# Out:
# low       2172
# medium    1317
# high        82
# Name: salary, dtype: int64

# %%
df2['salary'].value_counts()
# Out:
# low       5144
# medium    5129
# high      1155
# Name: salary, dtype: int64

# %%
df4=df1.pivot("Emp ID","dept","promotion_last_5years")
sns.heatmap(df4).get_figure().savefig('promdf1.png')

# %%
df5=df2.pivot("Emp ID","dept","promotion_last_5years")
sns.heatmap(df5).get_figure().savefig('promdf2.png')

# %%
df6=df1.pivot("Emp ID","dept","Work_accident")
sns.heatmap(df6).get_figure().savefig('workaccdf1.png')

# %%
df7=df2.pivot("Emp ID","dept","Work_accident")
sns.heatmap(df7).get_figure().savefig('workaccdf2.png')

# %%
df8=df1.pivot("Emp ID","dept","satisfaction_level")
sns.heatmap(df8).get_figure().savefig('satisfactiondf1.png')

# %%
df9=df2.pivot("Emp ID","dept","satisfaction_level")
sns.heatmap(df9).get_figure().savefig('satisfactiondf2.png')

# %%
def score_to_numeric(x):
    if x=='low':
        return 1
    if x=='medium':
        return 2
    if x=='high':
        return 3
df1['salary']=df1['salary'].apply(score_to_numeric)
def score_to_numeric(x):
    if x=='low':
        return 1
    if x=='medium':
        return 2
    if x=='high':
        return 3   
df2['salary']=df2['salary'].apply(score_to_numeric)
df1['salary']=df1['salary'].astype('float')
df2['salary']=df2['salary'].astype('float')

# %%
df10=df1.pivot("Emp ID","dept","salary")
sns.heatmap(df10).get_figure().savefig('salarydf1.png')

# %%
df11=df2.pivot("Emp ID","dept","salary")
sns.heatmap(df11).get_figure().savefig('salarydf2.png')

# %%
df12=df1.pivot("Emp ID","dept","average_montly_hours")
sns.heatmap(df12).get_figure().savefig('hoursdf1.png')

# %%
df13=df2.pivot("Emp ID","dept","average_montly_hours")
sns.heatmap(df13).get_figure().savefig('hoursdf2.png')
